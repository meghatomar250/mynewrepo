# %%
# %run ./validation_script.ipynb

# %%
# Import necessary functions from the script
# from validation_script import main

# Define paths to your input CSV files
file1 = '/Users/meghatomar/Downloads/Hcpfolder/HCP_DATA.csv'
file2 = '/Users/meghatomar/Downloads/Hcpfolder/HCP_DATA copy.csv'
primary_key = 'Subject'

# Call the main function to generate the report
report = main(file1, file2, primary_key)

# Display the report
print(report)
# Out:
# Total number of matching columns: 383
# Total number of rows in DataFrame 1: 100
# Total number of rows in DataFrame 2: 100
# Release mismatching values: 0.00%
# Acquisition mismatching values: 0.00%
# Gender mismatching values: 0.00%
# Age mismatching values: 0.00%
# 3T_Full_MR_Compl mismatching values: 0.00%
# T1_Count mismatching values: 0.00%
# T2_Count mismatching values: 0.00%
# 3T_RS-fMRI_Count mismatching values: 0.00%
# 3T_RS-fMRI_PctCompl mismatching values: 0.00%
# 3T_Full_Task_fMRI mismatching values: 0.00%
# 3T_tMRI_PctCompl mismatching values: 0.00%
# fMRI_WM_PctCompl mismatching values: 0.00%
# fMRI_Gamb_PctCompl mismatching values: 0.00%
# fMRI_Mot_PctCompl mismatching values: 0.00%
# fMRI_Lang_PctCompl mismatching values: 0.00%
# fMRI_Soc_PctCompl mismatching values: 0.00%
# fMRI_Rel_PctCompl mismatching values: 0.00%
# fMRI_Emo_PctCompl mismatching values: 0.00%
# 3T_dMRI_Compl mismatching values: 0.00%
# 3T_dMRI_PctCompl mismatching values: 0.00%
# ...

# %%
# Call the get_mismatch_records_for_column function to get mismatch records for a specific column
column_to_check = 'Noise_Comp'
mismatch_records = get_mismatch_records_for_column(file1, file2, primary_key, column_to_check)
mismatch_records
# Out:
# Empty DataFrame
# Columns: [Noise_Comp_df1, Noise_Comp_df2]
# Index: []

# %%
column_to_check = 'WM_Task_2bk_Tool_Median_RT_Target'
mismatch_records = get_mismatch_records_for_column(file1, file2, primary_key, column_to_check)
mismatch_records
# Out:
# Empty DataFrame
# Columns: [WM_Task_2bk_Tool_Median_RT_Target_df1, WM_Task_2bk_Tool_Median_RT_Target_df2]
# Index: []

# %%
column_to_check = 'WM_Task_2bk_Body_Median_RT_Target'
mismatch_records = get_mismatch_records_for_column(file1, file2, primary_key, column_to_check)
mismatch_records
# Out:
# Empty DataFrame
# Columns: [WM_Task_2bk_Body_Median_RT_Target_df1, WM_Task_2bk_Body_Median_RT_Target_df2]
# Index: []
